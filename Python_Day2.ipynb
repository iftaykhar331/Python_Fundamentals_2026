# %%
#Rules for declaring the variables in Python

# %%
firstname='Qureshi' #No space while declaring the variable

# %%
name1='Qureshi' #Variable name should not start with number

# %%
name2='Mohammad' #Vriable name should not contain a special characters

# %%
print(firstname, name1, name2)
# Out:
# Qureshi Qureshi Mohammad

# %%
#String Datatypes

# %%
name='Qureshi' #single quote

# %%
name2="Mohammad" #Double quote

# %%
print(name, name2)
# Out:
# Qureshi Mohammad

# %%
#string Methods

# %%
type(name)
# Out:
# str

# %%
fullname='mohammad qureshi'

# %%
print(fullname.title())
# Out:
# Mohammad Qureshi

# %%
print(fullname.upper())
# Out:
# MOHAMMAD QURESHI

# %%
print(fullname.lower())
# Out:
# mohammad qureshi
