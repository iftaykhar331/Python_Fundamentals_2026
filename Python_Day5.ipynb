# %%
#Organizing the list data type

# %%
cars=['kia', 'audi', 'maruthi', 'hyundai', 'wolksvagon', 'benz', 'suzuki', 'bmw']

# %%
print(cars) #originl approach
# Out:
# ['audi', 'benz', 'bmw', 'hyundai', 'kia', 'maruthi', 'suzuki', 'wolksvagon']

# %%
#List in alphabetical order (A-Z)

# %%
#Two combinations

# %%
1.Temporary Apporach...sorted

# %%
2.Permanent Apporach...sort

# %%
print(sorted(cars)) #Temporary Approach
# Out:
# ['audi', 'benz', 'bmw', 'hyundai', 'kia', 'maruthi', 'suzuki', 'wolksvagon']

# %%
cars.sort() #Permanent Approach

# %%
print(cars)
# Out:
# ['audi', 'benz', 'bmw', 'hyundai', 'kia', 'maruthi', 'suzuki', 'wolksvagon']

# %%
#Identifying how many cars are there in the list.....(len method)

# %%
len(cars)
# Out:
# 8

# %%
#Get output in opposite order(Z-A)

# %%
cars.reverse()

# %%
print(cars)
# Out:
# ['wolksvagon', 'suzuki', 'maruthi', 'kia', 'hyundai', 'bmw', 'benz', 'audi']

# %%
#introduction to slicing

# %%
#syntax of slicing

# %%
[start_value:stop_value:step_count]

# %%
students=['divya', 'harika', 'naveen', 'hafsa', 'karthik', 'vicky']

# %%
print(students)
# Out:
# ['divya', 'harika', 'naveen', 'hafsa', 'karthik', 'vicky']

# %%
#Note:Last value is always exclusive,to include the last value we have to increment to index by +1

# %%
#req:i want to get divya and harika in the slice?

# %%
print(students[0:1])
# Out:
# ['divya']

# %%
print(students[0:2])
# Out:
# ['divya', 'harika']

# %%
print(students[2:4])
# Out:
# ['naveen', 'hafsa']

# %%
print(students[0:6:2])
# Out:
# ['divya', 'naveen', 'karthik']

# %%
#Introduction to tuple data type

# %%
#Def: An immutable list is called as an tuple data type

# %%
#classification: It is classified as an immutable

# %%
#tuple is define as ()

# %%
area_size=(27,30) #cannot change the value as its immutable (fix value)

# %%
print(area_size)
# Out:
# (27, 30)

# %%
type(area_size)
# Out:
# tuple
