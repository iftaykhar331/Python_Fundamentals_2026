# %%
# Introduction to f strings

# %%
firstname='mohammad'

# %%
lastname='qureshi'

# %%
print(firstname)
# Out:
# mohammad

# %%
print(lastname)
# Out:
# qureshi

# %%
fullname= f"{firstname} {lastname}"

# %%
print(fullname.title())
# Out:
# Mohammad Qureshi

# %%
message= f"keep up the good work,{fullname.title()}"

# %%
print(message)
# Out:
# keep up the good work,Mohammad Qureshi

# %%
#Adding White Spaces to Strings

# %%
print("favourite_prog_lang:\npython\nc++\njava\nc\nswift\njavascript") # for list wise output using \n
# Out:
# favourite_prog_lang:
# python
# c++
# java
# c
# swift
# javascript

# %%
print("favourite_prog_lang:\n\tpython\n\tc++\n\tjava\n\tc\n\tswift\n\tjavascript") # for tab space using \t
# Out:
# favourite_prog_lang:
# 	python
# 	c++
# 	java
# 	c
# 	swift
# 	javascript

# %%
name=" python"

# %%
print(name)
# Out:
#  python

# %%
name.lstrip()
# Out:
# 'python'

# %%
name="python "

# %%
name.rstrip()
# Out:
# ' python'

# %%
name2="  python   "

# %%
name.strip()
# Out:
# 'python'
