# %%
# Introduction to list datatype :

# %%
Defination: A list is nothing but a collection of items declared in particular order.
Classification: It is classified as an mutable datatype
how to define the list : []

# %%
# Tuple Datatypes

# %%
Introduction to tuple datatype:

# %%
Defination: An immutable list is called a tuple datatype
Classification: It is classified as an immutable datatype
how do we define the tuple datatype -------> ()

# %%
dimension = ( 20, 60)

print(dimension)
# Out:
# (20, 60)

# %%
type(dimension)
# Out:
# tuple

# %%
dimension[0] = 25
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dimension[0] = 25
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Introduction to looping statements

# %%
Introduction to for loop :

# %%
# General Syntax :

# %%
for tempvar in mainvar:
    print(tempvar)

# %%
students = ['vicky','sudhakar','navya','neha','sai','david']

# %%
print(students)
# Out:
# ['vicky', 'sudhakar', 'navya', 'neha', 'sai', 'david']

# %%
message = f"keep up the good work, {students[0].title()}"

print(message)
# Out:
# keep up the good work, Vicky

# %%
message = f"keep up the good work, {students[1].title()}"

print(message)
# Out:
# keep up the good work, Sudhakar

# %%
for x in students:
    print(f"keep up the good work, {x.title()}")
# Out:
# keep up the good work, Vicky
# keep up the good work, Sudhakar
# keep up the good work, Navya
# keep up the good work, Neha
# keep up the good work, Sai
# keep up the good work, David

# %%
for x in students:
    print(f"keep up the good work, {x.title()}")
    print(f"i will be looking forward to receive your github url for the review, {x.title()}")
# Out:
# keep up the good work, Vicky
# i will be looking forward to receive your github url for the review, Vicky
# keep up the good work, Sudhakar
# i will be looking forward to receive your github url for the review, Sudhakar
# keep up the good work, Navya
# i will be looking forward to receive your github url for the review, Navya
# keep up the good work, Neha
# i will be looking forward to receive your github url for the review, Neha
# keep up the good work, Sai
# i will be looking forward to receive your github url for the review, Sai
# keep up the good work, David
# i will be looking forward to receive your github url for the review, David

# %%
# enhancement of the code....

# %%
for x in students:
    print(f"keep up the good work, {x.title()}")
    print(f"i will be looking forward to receive your github url for the review, {x.title()}.\n")
# Out:
# keep up the good work, Vicky
# i will be looking forward to receive your github url for the review, Vicky.
#
# keep up the good work, Sudhakar
# i will be looking forward to receive your github url for the review, Sudhakar.
#
# keep up the good work, Navya
# i will be looking forward to receive your github url for the review, Navya.
#
# keep up the good work, Neha
# i will be looking forward to receive your github url for the review, Neha.
#
# keep up the good work, Sai
# i will be looking forward to receive your github url for the review, Sai.
#
# keep up the good work, David
# i will be looking forward to receive your github url for the review, David.

# %%
print(students)
# Out:
# ['vicky', 'sudhakar', 'navya', 'neha', 'sai', 'david']

# %%
# this gap is called a indentation ( the gap below FOR syntax, before print)

# %%
for x in students:
print(f"keep up the good work, {x.title()}") #before print no gap so getting below error, so FOR loop syntax need to give space (indented block)
# Out:
#   Cell In[17], line 2
#     print(f"keep up the good work, {x.title()}")
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
for x in students:
    print(f"keep up the good work, {x.title()}")
    print(f"i will be looking forward to receive your github url for the review, {x.title()}.\n")

print("Thank you all for joining in the python sessions")
# Out:
# keep up the good work, Vicky
# i will be looking forward to receive your github url for the review, Vicky.
#
# keep up the good work, Sudhakar
# i will be looking forward to receive your github url for the review, Sudhakar.
#
# keep up the good work, Navya
# i will be looking forward to receive your github url for the review, Navya.
#
# keep up the good work, Neha
# i will be looking forward to receive your github url for the review, Neha.
#
# keep up the good work, Sai
# i will be looking forward to receive your github url for the review, Sai.
#
# keep up the good work, David
# i will be looking forward to receive your github url for the review, David.
#
# Thank you all for joining in the python sessions

# %%
# for above output, In syntax for x in students: last line is not in loop with above lines in syntax, its takig only last line as output
