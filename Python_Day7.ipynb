# %%
# Introduction to dictionaries

# %%
Def: A dictionary is a combination of key value pairs
Classification: It is classified as a mutable data type

# %%
How to define/declare the dictonary : {}

# %%
# I want to create a alien game

# %%
alien = {'color':'green', 'points':5}

# %%
print(alien)
# Out:
# {'color': 'green', 'points': 5}

# %%
type(alien)
# Out:
# dict

# %%
# Dictionary is represented as dict

# %%
# How to add a new key value pairs in the dictionary

# %%
# I want to add start_position: level1 will be the start positioin

# %%
alien['start_position'] ='level1'

# %%
print(alien)
# Out:
# {'color': 'green', 'points': 5, 'start_position': 'level1'}

# %%
# Req: How to access the new value pairs

# %%
Note: In the dictionary - keys will be acting as indexing points.

# %%
alien['color']
# Out:
# 'green'

# %%
alien['start_position']
# Out:
# 'level1'

# %%
alien['points']
# Out:
# 5

# %%
# give the key and get the value

# %%
# Create a new user account in instagram

# %%
user_account = {'username':'codetarining01', 'username': 'code', 'dob': '01-01-2020', 'passowrd': '54321'}

# %%
print(user_account)
# Out:
# {'username': 'code', 'dob': '01-01-2020', 'passowrd': '54321'}

# %%
# I want to delete a key value pair

# %%
# I want to delete a username

# %%
del user_account ['username']

# %%
print(user_account)
# Out:
# {'dob': '01-01-2020', 'passowrd': '54321'}

# %%
print(alien)
# Out:
# {'color': 'green', 'points': 5, 'start_position': 'level1'}

# %%
alien['level1'] # cannot use key for output, see below error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 alien['level1'] # cannot use key for output
#
# KeyError: 'level1'

# %%
# Implementation of a for loop on top of a dictionary

# %%
# General syntax of a dictionary

# %%
for tempvar, tempvar2 in mainvar.items():
    print(tempvar1)
    print(tempvar2)

# %%
print(alien)
# Out:
# {'color': 'green', 'points': 5, 'start_position': 'level1'}

# %%
for k,v in alien.items():
    print(k)
    print(v)
# Out:
# color
# green
# points
# 5
# start_position
# level1

# %%
for k,v in alien.items():
    print(f"key: {k}"
    print(f"value: {v}"\n)
# Out:
#   Cell In[23], line 3
#     print(f"value: {v}"\n)
#                         ^
# SyntaxError: unexpected character after line continuation character

# %%
for k,v in alien.items:
    print(f"key: {k}")
    print(f"value: {v}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 for k,v in alien.items:
#       2     print(f"key: {k}")
#       3     print(f"value: {v}")
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
for k,v in alien.items():
    print(f"key: {k}")
    print(f"value: {v}")
# Out:
# key: color
# value: green
# key: points
# value: 5
# key: start_position
# value: level1

# %%
for k,v in alien.items():
    print(f"key: {k}")
    print(f"value: {v}\n")
# Out:
# key: color
# value: green
#
# key: points
# value: 5
#
# key: start_position
# value: level1
